# %% [markdown]
# <a href="https://colab.research.google.com/github/rehan1124/Codebasics-Math-And-Statistics-For-AI-Data-Science/blob/main/Dataframe_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/movies.csv")
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
print("Number of rows and columns: ", df.shape)
# Out:
# Number of rows and columns:  (37, 10)

# %%
print("All column names:\n", df.columns)
# Out:
# All column names:
#  Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
print("What movie industries are present? ", df.industry.unique())
# Out:
# What movie industries are present?  ['Bollywood' 'Hollywood']

# %%
print("What languages are supported for all movies? ", df["language"].unique())
# Out:
# What languages are supported for all movies?  ['Bengali' 'English' 'Hindi' 'Kannada' 'Telugu']

# %%
print("How many Hollywood-Bollywood movies do we have?")
df.industry.value_counts()
# df.industry.count()
# Out:
# How many Hollywood-Bollywood movies do we have?
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %% [markdown]
# How many movies do we have for each and every language?

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %% [markdown]
# **Subset with Title, IMDB rating and Industry only**

# %%
df_subset1 = df[["title", "imdb_rating", "industry"]]
df_subset1.head(5)
# Out:
#                                          title  imdb_rating   industry
# 0                              Pather Panchali          8.3  Bollywood
# 1  Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                        Thor: The Dark World           6.8  Hollywood
# 3                              Thor: Ragnarok           7.9  Hollywood
# 4                      Thor: Love and Thunder           6.8  Hollywood

# %% [markdown]
# **Movies between year 2000 and 2010 only**

# %%
df[(df.release_year >= 2000) & (df.release_year < 2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 8                  Gladiator  Hollywood          2000          8.5
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# ...

# %% [markdown]
# **Only "Marvel Studios" movies**

# %%
df[df.studio == "Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %% [markdown]
# **Quick stats for our data**

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %% [markdown]
# **Movies with maximum and minimum IMDB ratings**

# %%
df[(df.imdb_rating == df.imdb_rating.max()) | (df.imdb_rating == df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %% [markdown]
# **Adding new column to show movie age w.r.t year 2024**

# %%
df["age"] = df.release_year.apply(lambda x: 2024 - x)
df.head(5)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   69
# 1      USD  English    2
# ...

# %% [markdown]
# **Add Profit % column to existing dataframe**

# %%
df["Profit %"] = df.apply(lambda x: ((x["revenue"] - x["budget"]) / x["budget"]) * 100, axis=1)
df.sample(5)
# Out:
#                                  title   industry  release_year  imdb_rating  \
# 24                    Bajirao Mastani   Bollywood          2015          7.2
# 18              Avengers: Infinity War  Hollywood          2018          8.4
# 17                   Avengers: Endgame  Hollywood          2019          8.4
# 19  Captain America: The First Avenger  Hollywood          2011          6.9
# 30                   Bajrangi Bhaijaan  Bollywood          2015          8.1
#
#                studio  budget  revenue      unit currency language  age  \
# 24                NaN     1.4      3.5  Billions      INR    Hindi    9
# 18     Marvel Studios   400.0   2048.0  Millions      USD  English    6
# 17     Marvel Studios   400.0   2798.0  Millions      USD  English    5
# 19     Marvel Studios   216.7    370.6  Millions      USD  English   13
# 30  Salman Khan Films   900.0  11690.0  Millions      INR    Hindi    9
#
#        Profit %
# 24   150.000000
# 18   412.000000
# 17   599.500000
# ...

# %% [markdown]
# **Indexes**

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index("title", inplace=True)
df.sample(5)
# Out:
#                            industry  release_year  imdb_rating  \
# title
# The Pursuit of Happyness  Hollywood          2006          8.0
# Taare Zameen Par          Bollywood          2007          8.3
# Avatar                    Hollywood          2009          7.8
# Parasite                  Hollywood          2019          8.5
# K.G.F: Chapter 2          Bollywood          2022          8.4
#
#                                      studio  budget  revenue      unit  \
# title
# The Pursuit of Happyness  Columbia Pictures    55.0    307.1  Millions
# Taare Zameen Par                        NaN   120.0   1350.0  Millions
# Avatar                     20th Century Fox   237.0   2847.0  Millions
# Parasite                                NaN    15.5    263.1  Millions
# K.G.F: Chapter 2              Hombale Films     1.0     12.5  Billions
#
#                          currency language  age     Profit %
# title
# The Pursuit of Happyness      USD  English   18   458.363636
# ...

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %% [markdown]
# **About `loc`**

# %%
df.loc["Pather Panchali"]
# Out:
# industry                        Bollywood
# release_year                         1955
# imdb_rating                           8.3
# studio          Government of West Bengal
# budget                            70000.0
# revenue                          100000.0
# unit                            Thousands
# currency                              INR
# language                          Bengali
# age                                    69
# Profit %                        42.857143
# Name: Pather Panchali, dtype: object

# %%
df.loc[["Pather Panchali", "Doctor Strange in the Multiverse of Madness"]]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# Pather Panchali                              70000.0  100000.0  Thousands
# Doctor Strange in the Multiverse of Madness    200.0     954.8   Millions
#
#                                             currency language  age    Profit %
# title
# ...

# %% [markdown]
# **About `iloc`**

# %%
df.iloc[4]
# Out:
# industry             Hollywood
# release_year              2022
# imdb_rating                6.8
# studio          Marvel Studios
# budget                   250.0
# revenue                  670.0
# unit                  Millions
# currency                   USD
# language               English
# age                          2
# Profit %                 168.0
# Name: Thor: Love and Thunder , dtype: object

# %%
df.iloc[5: 11]
# Out:
#                            industry  release_year  imdb_rating  \
# title
# The Shawshank Redemption  Hollywood          1994          9.3
# Interstellar              Hollywood          2014          8.6
# The Pursuit of Happyness  Hollywood          2006          8.0
# Gladiator                 Hollywood          2000          8.5
# Titanic                   Hollywood          1997          7.9
# It's a Wonderful Life     Hollywood          1946          8.6
#
#                                              studio  budget  revenue  \
# title
# The Shawshank Redemption  Castle Rock Entertainment   25.00     73.3
# Interstellar                  Warner Bros. Pictures  165.00    701.8
# The Pursuit of Happyness          Columbia Pictures   55.00    307.1
# Gladiator                      Universal Pictures    103.00    460.5
# Titanic                          Paramount Pictures  200.00   2202.0
# It's a Wonderful Life                 Liberty Films    3.18      3.3
#
# ...

# %% [markdown]
# **Resetting index**

# %%
df.reset_index(inplace=True)
df.sample(3)
# Out:
#                        title   industry  release_year  imdb_rating  \
# 6               Interstellar  Hollywood          2014          8.6
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 15             Jurassic Park  Hollywood          1993          8.2
#
#                    studio  budget  revenue      unit currency language  age  \
# 6   Warner Bros. Pictures   165.0    701.8  Millions      USD  English   10
# 7       Columbia Pictures    55.0    307.1  Millions      USD  English   18
# 15     Universal Pictures    63.0   1046.0  Millions      USD  English   31
#
#        Profit %
# 6    325.333333
# 7    458.363636
# 15  1560.317460
