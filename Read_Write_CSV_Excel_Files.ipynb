# %% [markdown]
# <a href="https://colab.research.google.com/github/rehan1124/Codebasics-Math-And-Statistics-For-AI-Data-Science/blob/main/Read_Write_CSV_Excel_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **Stock data**

# %%
df = pd.read_csv("/content/stock_data.csv")
df
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
# 5                       TATA            5.6         -1       n.a.
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani
# 5     ratan tata

# %% [markdown]
# **Skipping 1st row from datasource**

# %%
df = pd.read_csv("/content/stock_data.csv", skiprows=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# **Renaming columns**

# %%
df = pd.read_csv("/content/stock_data.csv", header=1, names=["Stock_Symbol", "EPS", "Revenue", "Price", "People"])
df
# Out:
#   Stock_Symbol            EPS  Revenue Price         People
# 0        GOOGL          27.82       87   845     larry page
# 1          WMT           4.61      484    65           n.a.
# 2         MSFT             -1       85    64     bill gates
# 3         RIL   not available       50  1023  mukesh ambani
# 4         TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# **Reading only 1st 4 rows**

# %%
df = pd.read_csv("/content/stock_data.csv", header=1, names=["Stock_Symbol", "EPS", "Revenue", "Price", "People"], nrows=4)
df
# Out:
#   Stock_Symbol            EPS  Revenue  Price         People
# 0        GOOGL          27.82       87    845     larry page
# 1          WMT           4.61      484     65           n.a.
# 2         MSFT             -1       85     64     bill gates
# 3         RIL   not available       50   1023  mukesh ambani

# %%
df = pd.read_csv("/content/stock_data.csv", header=1, names=["Stock_Symbol", "EPS", "Revenue", "Price", "People"], na_values={"EPS": ["not available"],
                                                                                                                              "People": ["n.a."],
                                                                                                                              "Price": ["n.a."]}
                 )
df
# Out:
#   Stock_Symbol    EPS  Revenue   Price         People
# 0        GOOGL  27.82       87   845.0     larry page
# 1          WMT   4.61      484    65.0            NaN
# 2         MSFT  -1.00       85    64.0     bill gates
# 3         RIL     NaN       50  1023.0  mukesh ambani
# 4         TATA   5.60       -1     NaN     ratan tata

# %%
df["Price_To_Earning_Ration"] = df["Price"] / df["EPS"]
df
# Out:
#   Stock_Symbol    EPS  Revenue   Price         People  Price_To_Earning_Ration
# 0        GOOGL  27.82       87   845.0     larry page                30.373832
# 1          WMT   4.61      484    65.0            NaN                14.099783
# 2         MSFT  -1.00       85    64.0     bill gates               -64.000000
# 3         RIL     NaN       50  1023.0  mukesh ambani                      NaN
# 4         TATA   5.60       -1     NaN     ratan tata                      NaN

# %%
df.to_csv("Price_To_Earning_Ratio.csv", index=False)
