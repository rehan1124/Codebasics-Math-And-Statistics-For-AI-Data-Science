# %% [markdown]
# <a href="https://colab.research.google.com/github/rehan1124/Codebasics-Math-And-Statistics-For-AI-Data-Science/blob/main/Read_Write_Excel_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_movies = pd.read_excel("/content/movies_db.xlsx", sheet_name="movies")
df_movies.head()
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5
# 3          2017          7.9  Marvel Studios            5
# 4          2022          6.8  Marvel Studios            5

# %%
def standardize_currency(currency):
    if currency in ("$$", "Dollars"):
        return "USD"
    return currency

df_financials = pd.read_excel("/content/movies_db.xlsx", sheet_name="financials", converters={"currency": standardize_currency})
df_financials.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD
# 3       104   180.0    854.0  Millions      USD
# 4       105   250.0    670.0  Millions      USD

# %%
df_movies_financials = pd.merge(df_movies[["movie_id", "title", "industry", "release_year", "imdb_rating", "studio"]], df_financials[["movie_id", "budget", "revenue", "unit", "currency"]], on="movie_id")
df_movies_financials.head()
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
#
#    release_year  imdb_rating          studio  budget  revenue      unit  \
# 0          2022          8.4   Hombale Films     1.0     12.5  Billions
# 1          2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2          2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3          2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4          2022          6.8  Marvel Studios   250.0    670.0  Millions
#
#   currency
# 0      INR
# 1      USD
# 2      USD
# 3      USD
# 4      USD
